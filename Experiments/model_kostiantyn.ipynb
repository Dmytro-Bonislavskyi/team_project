# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, Dropout, MaxPooling1D
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder


# index,Severity,Start_Time,End_Time,Start_Lat,Start_Lng,Distance(mi),City,County,State,Weather_Timestamp,Temperature(F),Wind_Chill(F),Humidity(%),Pressure(in),Visibility(mi),Wind_Direction,Wind_Speed(mph),Precipitation(in),Weather_Condition,Amenity,Bump,Crossing,Give_Way,Junction,No_Exit,Railway,Roundabout,Station,Stop,Traffic_Calming,Traffic_Signal,Turning_Loop,Sunrise_Sunset,Accident_Date,Accident_Year,Accident_Month,Accident_Day,accident_weekday,is_weekend,is_holiday,Accident_Time

# Load and preprocess the dataset
# Assume `data` is a DataFrame containing your dataset
data = pd.read_csv('../data/processed/Los_Angeles_Accidents_Complete_2016_2023.csv')
pd.options.display.max_columns = None

columns_to_drop = ['index', 'Start_Time', 'End_Time', 'Distance(mi)', 'City', 'County', 'State', 'Accident_Date']

data = data.drop(columns_to_drop, axis=1)
# Out:
# 2024-08-09 17:55:00.387107: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-09 17:55:00.405920: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_years(data_frame, column):
  return data_frame[column].apply(lambda date: pd.to_numeric(date[0:4]))

def get_months(data_frame, column):
  return data_frame[column].apply(lambda date: pd.to_numeric(date[5:7]))

def get_days(data_frame, column):
  return data_frame[column].apply(lambda date: pd.to_numeric(date[8:10]))

def get_hours(data_frame, column):
  return data_frame[column].apply(lambda date: pd.to_numeric(date[11:13]))

data['Weather_Timestamp_Year'] = get_years(data, 'Weather_Timestamp')
data['Weather_Timestamp_Month'] = get_months(data, 'Weather_Timestamp')
data['Weather_Timestamp_Day'] = get_days(data, 'Weather_Timestamp')
data['Weather_Timestamp_Time'] = get_hours(data, 'Weather_Timestamp')

data
# Out:
#         Severity  Start_Lat   Start_Lng    Weather_Timestamp  Temperature(F)  \
# 0              2  34.078926 -118.289040  2016-06-21 10:47:00            82.9
# 1              3  34.091179 -118.239471  2016-06-21 10:47:00            82.9
# 2              3  34.037239 -118.309074  2016-06-21 10:47:00            82.9
# 3              3  34.027458 -118.274490  2016-06-21 10:47:00            82.9
# 4              3  33.947544 -118.279434  2016-06-21 11:53:00            80.1
# ...          ...        ...         ...                  ...             ...
# 156486         2  34.036930 -118.438770  2019-08-22 16:51:00            72.0
# 156487         3  34.075790 -118.276680  2019-08-23 03:52:00            67.0
# 156488         2  34.023790 -118.276390  2019-08-23 12:52:00            81.0
# 156489         2  34.070610 -118.263910  2019-08-23 13:52:00            82.0
# 156490         2  34.043650 -118.443730  2019-08-23 15:51:00            74.0
#
#         Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0           64.925012         47.0         29.95            10.0
# 1           64.925012         47.0         29.95            10.0
# 2           64.925012         47.0         29.95            10.0
# 3           64.925012         47.0         29.95            10.0
# 4           64.925012         52.0         29.96            10.0
# ...               ...          ...           ...             ...
# 156486      72.000000         76.0         29.57            10.0
# 156487      67.000000         79.0         29.62             7.0
# 156488      81.000000         49.0         29.66             8.0
# 156489      82.000000         47.0         29.65             9.0
# 156490      74.000000         66.0         29.64            10.0
#
#        Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 0            Variable              4.6           0.003435             Clear
# 1            Variable              4.6           0.003435             Clear
# 2            Variable              4.6           0.003435             Clear
# 3            Variable              4.6           0.003435             Clear
# 4                 ESE              9.2           0.003435             Clear
# ...               ...              ...                ...               ...
# 156486             SW              8.0           0.000000              Fair
# 156487           CALM              0.0           0.000000            Cloudy
# 156488           CALM              0.0           0.000000              Fair
# 156489           CALM              0.0           0.000000              Fair
# 156490              W              8.0           0.000000              Fair
#
#         Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 0         False  False     False     False      True    False    False
# 1         False  False     False     False     False    False    False
# 2         False  False     False     False     False    False    False
# 3         False  False     False     False     False    False    False
# 4         False  False     False     False     False    False    False
# ...         ...    ...       ...       ...       ...      ...      ...
# 156486    False  False     False     False      True    False    False
# 156487    False  False     False     False     False    False    False
# 156488    False  False     False     False     False    False    False
# 156489    False  False     False     False      True    False    False
# 156490    False  False     False     False      True    False    False
#
#         Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0            False    False  False            False           False
# 1            False    False  False            False           False
# 2            False     True  False            False           False
# 3            False    False  False            False           False
# 4            False    False  False            False           False
# ...            ...      ...    ...              ...             ...
# 156486       False    False  False            False           False
# 156487       False    False  False            False           False
# 156488       False    False  False            False           False
# 156489       False    False  False            False           False
# 156490       False    False  False            False           False
#
#         Turning_Loop Sunrise_Sunset  Accident_Year  Accident_Month  \
# 0              False            Day           2016               6
# 1              False            Day           2016               6
# 2              False            Day           2016               6
# 3              False            Day           2016               6
# 4              False            Day           2016               6
# ...              ...            ...            ...             ...
# 156486         False            Day           2019               8
# 156487         False          Night           2019               8
# 156488         False            Day           2019               8
# 156489         False            Day           2019               8
# 156490         False            Day           2019               8
#
#         Accident_Day  accident_weekday  is_weekend  is_holiday  Accident_Time  \
# 0                 21                 1       False       False             10
# 1                 21                 1       False       False             10
# 2                 21                 1       False       False             10
# 3                 21                 1       False       False             10
# 4                 21                 1       False       False             11
# ...              ...               ...         ...         ...            ...
# 156486            22                 3       False       False             17
# 156487            23                 4       False       False              4
# 156488            23                 4       False       False             12
# 156489            23                 4       False       False             13
# 156490            23                 4       False       False             15
#
#         Weather_Timestamp_Year  Weather_Timestamp_Month  \
# 0                         2016                        6
# 1                         2016                        6
# 2                         2016                        6
# 3                         2016                        6
# 4                         2016                        6
# ...                        ...                      ...
# 156486                    2019                        8
# 156487                    2019                        8
# 156488                    2019                        8
# 156489                    2019                        8
# 156490                    2019                        8
#
#         Weather_Timestamp_Day  Weather_Timestamp_Time
# 0                          21                      10
# 1                          21                      10
# 2                          21                      10
# 3                          21                      10
# 4                          21                      11
# ...                       ...                     ...
# 156486                     22                      16
# 156487                     23                       3
# 156488                     23                      12
# 156489                     23                      13
# 156490                     23                      15
#
# [156491 rows x 38 columns]

# %%
data = data.drop('Weather_Timestamp', axis=1)

# %%
def onehot_encode(dataframe, columns, prefixies):
  dataframe = dataframe.copy()
  for column, prefix in zip(columns, prefixies):
    dummies = pd.get_dummies(dataframe[column], prefix=prefix, dtype='int')
    dataframe = pd.concat([dataframe, dummies], axis=1)
    dataframe = dataframe.drop(column, axis=1)
  return dataframe

# %%
{column: len(data[column].unique()) for column in data.columns if data.dtypes[column] == 'object' }
# Out:
# {'Wind_Direction': 24, 'Weather_Condition': 33, 'Sunrise_Sunset': 2}

# %%
data = onehot_encode(
  data,
  ['Wind_Direction', 'Weather_Condition'],
  ['WD', 'WC']
)

# %%
def convert_binary_to_boolean(dataframe, column):
  return dataframe[column].apply(lambda x: 1 if x == 'Day' else 0)

# %%
data['Sunrise_Sunset'] = convert_binary_to_boolean(data, 'Sunrise_Sunset')

# %%
y = data['Severity'].copy()
X = data.drop('Severity', axis=1).copy()

# %%
# To make severity values from 0 to 3
y=y-1

# %%
X = X.astype(float)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=100)

# %%
inputs = tf.keras.Input(shape=(X.shape[1]))
x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(4, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 32
epochs = 20

history = model.fit(X_train, y_train, validation_split=0.2, batch_size=batch_size, epochs=epochs, callbacks=[
  tf.keras.callbacks.ReduceLROnPlateau(),
  tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3
  )
])
# Out:
# Epoch 1/20
# 2739/2739 [==============================] - 3s 900us/step - loss: 0.4860 - accuracy: 0.7945 - val_loss: 0.4640 - val_accuracy: 0.8031 - lr: 0.0010
# Epoch 2/20
# 2739/2739 [==============================] - 2s 877us/step - loss: 0.4534 - accuracy: 0.8074 - val_loss: 0.4560 - val_accuracy: 0.8083 - lr: 0.0010
# Epoch 3/20
# 2739/2739 [==============================] - 2s 902us/step - loss: 0.4435 - accuracy: 0.8122 - val_loss: 0.4500 - val_accuracy: 0.8126 - lr: 0.0010
# Epoch 4/20
# 2739/2739 [==============================] - 2s 888us/step - loss: 0.4337 - accuracy: 0.8177 - val_loss: 0.4411 - val_accuracy: 0.8155 - lr: 0.0010
# Epoch 5/20
# 2739/2739 [==============================] - 2s 882us/step - loss: 0.4255 - accuracy: 0.8230 - val_loss: 0.4359 - val_accuracy: 0.8204 - lr: 0.0010
# Epoch 6/20
# 2739/2739 [==============================] - 2s 904us/step - loss: 0.4163 - accuracy: 0.8269 - val_loss: 0.4326 - val_accuracy: 0.8205 - lr: 0.0010
# Epoch 7/20
# 2739/2739 [==============================] - 2s 891us/step - loss: 0.4078 - accuracy: 0.8310 - val_loss: 0.4285 - val_accuracy: 0.8235 - lr: 0.0010
# Epoch 8/20
# 2739/2739 [==============================] - 2s 910us/step - loss: 0.4007 - accuracy: 0.8350 - val_loss: 0.4297 - val_accuracy: 0.8271 - lr: 0.0010
# Epoch 9/20
# 2739/2739 [==============================] - 2s 894us/step - loss: 0.3960 - accuracy: 0.8369 - val_loss: 0.4270 - val_accuracy: 0.8259 - lr: 0.0010
# Epoch 10/20
# 2739/2739 [==============================] - 2s 878us/step - loss: 0.3915 - accuracy: 0.8386 - val_loss: 0.4214 - val_accuracy: 0.8296 - lr: 0.0010
# Epoch 11/20
# 2739/2739 [==============================] - 2s 889us/step - loss: 0.3879 - accuracy: 0.8407 - val_loss: 0.4220 - val_accuracy: 0.8281 - lr: 0.0010
# Epoch 12/20
# 2739/2739 [==============================] - 2s 908us/step - loss: 0.3834 - accuracy: 0.8429 - val_loss: 0.4270 - val_accuracy: 0.8278 - lr: 0.0010
# Epoch 13/20
# 2739/2739 [==============================] - 2s 888us/step - loss: 0.3802 - accuracy: 0.8429 - val_loss: 0.4219 - val_accuracy: 0.8278 - lr: 0.0010
